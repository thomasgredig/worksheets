# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
# Accompanying Worksheets to Class Notes, also printed in [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0GJD4DNNY).
#
# #  Worksheet 21: Random Walk and Simulations
#
# - Simulate 1D random walk; compute $\langle x \rangle$ and $\langle x^2 \rangle$ vs steps; compare to theory;
# - Show distribution of final positions approaches normal;
# - Compute standard error across multiple trials.

# %%
import numpy.random as npr  # random numpy module
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Irrational Numbers
#
# A circle of radius 1 has an area of $\pi$ and fits into a square box of area 4. If we focus on one quadrant with area 1, the quarter circle then has an area $\pi/4$. Based on this, a  Monte Carlo algorithm is written to compute $\pi$.

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
#
# ## Task 2: Monte Carlo Approach to Pi
#
# Use a square of length 1. Create 1 million random points in that square at positions $\langle x_i, y_i \rangle$ and compute the distance to the origin. If the distance is 1 or less, then it is inside the circle quadrant, otherwise it is outside. Counting how many dots are in the square (area = 1) and how many are in the circle quadrant (area = $\pi/4$), then you can determine the numbrer $\pi$.
#
# </div>

# %%
# Random Number

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
# # Random Walk
#
# ## Task 2: Mean displacement and mean squared displacement in 1D
#
# For a walker that takes steps +1 or −1 with equal probability in 1D, the expected displacement $\langle x \rangle = 0$ and $\langle x^2 \rangle = N$.
#
# - Write a simulation that returns both expectation values for $N$ steps using $M$ simulations (to compute the average).
# - Use $M=10'000$ and run the simulation for multiple $N$.
# - Make a graph of $\langle x \rangle$ vs. $N$ and also $\langle x^2 \rangle$ vs. $N$.

# %%
# Simlulation

# %%
# your graph
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
# ## Task 3: Mean displacement and mean squared displacement in 2D
#
# Repeat the same task for the same parameters, but now the walker can move in 2D; i.e. left, right, up, and down (four movements).

# %%
# simulation

# %%
# your graph
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
# ## Optional: Discussion
#
# Discuss your results from 1D and 2D random walks. How do they differ?

# %% [markdown]
# --> YOUR DISCUSSION <--

# %% [markdown]
# The End.
