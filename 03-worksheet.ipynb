# %% [markdown]
# Accompanying Worksheets to Notes in [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0GJD4DNNY).

# %% [markdown]
# # Worksheet 3: Data Types, Loops, Functions
#
# - Define Python variables, compute kinetic energy, escape velocity, and thermal speed for given inputs;
# - Print and format the output using f-strings;
# - Use a loop and implement breaks using conditional statements.

# %% [markdown]
# <div style="background:#e6f2ff; padding:12px 14px; border-radius:8px;">
#
# ## Task 1
#
# Write the types of the following Python data types into your notebook, then use `type(a1)` etc to check the data type for each variable.
#
# ``` python
# a1 = 3.2
# a2 = "300"
# a3 = (5)
# a4 = (8,"string")
# a5 = [True]
# a6 = False
# a7 = {4,5}
# a8 = {4:5}
# a9 = (3,)
# ```

# %%
# Check the data type

# %% [markdown]
# ### Zero-based Indexing
#
# The first number is always 0 in Python. This is called zero-based indexing used in Python, C, and Java. Some languages (R, Julia, Fortran, Lua) use one-based indexing. Elements from Tuples and Lists are accessed via square brackets, for example, this list has 4 elements, the first is called "0" and the last element is "3".
#
# ``` python
# b1 = [5,10,15,20]
# b1[0], b1[3], len(b1)
# ```

# %%
# Copy the code here (guess the output before running the cell)

# %% [markdown]
# The last element is also called "-1", the second last "-2" and so on. Retrieve the last element from the following list `b2` and store it in the variable `b2_last`
#
# ``` python
# b2 = [n for n in range(10)] # given list
# b2_last = ...
# ```

# %% [markdown]
# <div style="background:#e6f2ff; padding:12px 14px; border-radius:8px;">
#
# ## Task 2
#
# Extract the "cookie" from the following structure in `d1` using element access, secondly show how to access the second last letter from "pear"; i.e. the "a" in this case.
#
# ``` python
# d1 = [4, "apple",["pear",2,"cookie"],3,"date"]
# ```

# %%
# get the cookie

# get the second to last letter from "pear"

# %% [markdown]
# <div style="background:#e6f2ff; padding:12px 14px; border-radius:8px;">
#
# ## Task 3
#
# Use the following formula to compute the escape speed on the moon use an `f-string` with appropriate formatting and untis.
#
# $$
# v_e = \sqrt{ \frac{2G M_\text{moon}}{R_\text{moon}} }
# $$
#
# Use $G=6.67 \times  10^{-11}$ m<sup>3</sup> / kg / s<sup>2</sup> and $M=7.35 \times 10^{22}$ kg and $R = 1737$ km.
#
# Example for `f-strings` use `print(f"The answer is {ans:.3g} m/s")` where `ans` is a variable with the answer. Using either `.3g` or `.3f` for significant digits or floating precision as discussed in class.

# %%
# Your Code to compute escape speed and use the f-string to print a formated response with units.

# %% [markdown]
# <div style="background:#e6f2ff; padding:12px 14px; border-radius:8px;">
#
# ## Task 4
#
# Find the sum of the first 200 Fibonacci numbers (see worksheet 2).

# %%
from eulerlib import first_n_fibo
# Your Code to add the numbers with a `for` loop

# %% [markdown]
# <div style="background:#e6f2ff; padding:12px 14px; border-radius:8px;">
#
# ## Task 5
#
# Use a `while` statement to add integers up; i.e. $1+2+3+\ldots$, such that the total is less than 10'000. What is the last number before your reach the maximum?
#
# </div>

# %%
# Your WHILE loop
