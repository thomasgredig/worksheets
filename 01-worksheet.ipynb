# %% [markdown]
# ## Worksheet 1: Motivation and Literature Search
#
# - Motivate topics; review computational physics resource letters;
# - Select a publication from CP-3 and discuss the findings;
# - Use a publication from the American Journal of Physics that numerically solves a problem; extract the model, inputs, outputs and validation method;
# - Identify a physics problem that lacks a closed-form solution; write a motivation for a computational approach.

# %% [markdown]
# ## Task 1
#
# List one of the 3 technical skills or 6 physical skills that AAPT recommends for all physicists; briefly describe why it is important to you.

# %% [markdown]
# ::: ADD THE SKILL

# %% [markdown]
# ## Task 2
#
# Access the article CP-3 to: https://pubs.aip.org/aapt/ajp/article/91/1/7/2872636/Resource-Letter-CP-3-Computational-physics and select one reference that interests you:

# %% [markdown]
# ::: ADD YOUR REFERENCE

# %% [markdown]
# ## Task 3
#
# Identify a physics problem that can be solved with numerical methods; describe briefly why

# %% [markdown]
# ::: ADD YOUR PROBLEM and EXPLANATION
