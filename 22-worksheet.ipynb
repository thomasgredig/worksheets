# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
# Accompanying Worksheets to Class Notes, also printed in [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0GJD4DNNY).
#
# # Markov Chain Monte Carlo and Review
#
# Markov Chain Monte Carlo (MCMC) is a computational technique used for integrating functions with many degrees of freedom or handling special probability distributions, so-called sampling from Bayesian posterior distributions. It has applications in various fields, including *machine learning* and *natural language processing*.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %% [markdown]
# ## Course Learning Goals
#
# A.	Summarize Literature on Computational Physics
# B.	Write Markdown Documentation using LaTeX Formatted Equations
# C.	Translate Physical Models into Python Code
# D.	Organize Jupyter Notebooks to Solve and Document Physics Problems
# E.	Proficiently Program in Python for Scientific Computation
# F.	Analyze and Fit Curves to Experimental Data
# G.	Solve Linear Equations, Find Roots of Transcendental Functions
# H.	Apply Numerical Methods to Solve Differential Equations and Integration
# I.	Symbolically Solve Systems of Equations, Integrals, and Differential Equations
# J.	Visualize Data and Make Professional Graphics and Animations
# K.	Develop and Implement Algorithms for Numerical Integration
# L.	Apply Classical Monte Carlo Principles with Metropolis-Hastings Algorithm
# M.	Apply Random Numbers to Solve Random Walk, Radioactive Decay, and 2D Ising Model
# N.	Communicate Results and Prepare Authentic Presentations
# O.	Subdivide a Model into Manageable Computational Tasks
# P.	Test, Document and Validate Code
# Q.	Choose Appropriate Scales and Units and Extract Physical Insight of Problems

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
#
# ## Task 1: Review an Objective
#
# Choose one of the objectives listed above and briefly describe an example and write a short code illustrating this example. Share it with another person.

# %% [markdown]
# ### Object + Description
#
# Add a brief description

# %%
# add your example code for the example above.

# %% [markdown]
# ## Monte Carlo Method
#
# The most efficient way to integrate high-dimensional integrals is often by Monte Carlo method. For illustration, we will solve one-dimensional integrals first. You can approximate an integral as follows using *simple sampling*, which means that we randomly choose numbers $x_i$ from a uniform distribution `random.uniform(a,b)` with $p(x) = 1/(b-a)$:
#
# $$
# \int_a^b f(x) dx \approx \frac{(b-a)}{N} \left[  \sum_{i=1}^N f(x_i) \right]
# $$
#
# The random numbers $x_i$ could be sorted in increasing fashion from $a$ to $b$. Subsequently, the average distance between them would approach approximately $(b-a)/N$, so we can pull this factor out and for sufficiently large $N$ and express the *integral* with the summation of random points.

# %% [markdown]
# <style>
# .box{padding:12px 14px;border-radius:8px;background:#e6f2ff;color:#0b1f33} @media(prefers-color-scheme:dark){  .box{background:#0b2540;color:#e6f2ff} }
# </style>
# <div class="box">
#
#
# ## Task 2: Monte Carlo Approach to Integration (Optional)
#
# Integrate $s = \int_0^1 \frac{dx}{1+x^2}$ using the following algorithm.
#
# ### Monte Carlo Simple Sampling Algorithm
#
# -   initialize `a`, `b`, and `N`
# -   define the function $f(x) = \frac{1}{1+x^2}$
# -   generate `N` random numbers $x_i$ in the range between `a` and `b`
# -   evaluate $f(x_i)$ for each random point and compute the sum
# -   normalize the result with a factor $(b-a)/N$
# </div>

# %%
# Your code
a = 0
b = 1
def f(x): return 1 # replace with the given function

s_MC = 0 # replace with the computation

# %%
# Random Number
s_quad = quad(f,a,b)
print(f"Quadrature: {s_quad[0]:.5f}," + 
f" Monte Carlo: {s_MC:.5f}")
# Out:
# Quadrature: 1.00000, Monte Carlo: 0.00000

# %% [markdown]
# The End.
