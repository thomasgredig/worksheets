# %% [markdown]
# # Final Project Model
#
# This is a template. Please complete all sections.
#
# Submit a short proposal that demonstrates (i) a well-defined computational physics question, with (ii) a tractable model you can implement and validate in the context of this course.

# %% [markdown]
# ## Theme / Title (and one-paragraph motivation)
#
# Provide: Project title (specific, not “Monte Carlo simulation”)
#
# Theme area (e.g., mechanics, diffusion/transport, statistical mechanics, electromagnetism, data-driven modeling, quantum systems)
#
# **Motivation paragraph** answering:
#
# - What physical phenomenon are you studying?
#
# - Why is it interesting (scientifically, technologically, or personally)?
#
# - What is the computational challenge (no closed form, noisy data, nonlinear dynamics, high-dimensional integrals, etc.)? Why is computation necessary to solve this problem?
#
# ### Example titles
#
# - "Trajectories of Tennis Balls using Spin and Drag in Authentic Environments"
#
# - "Water Evaporation Study of a Californian Dam"
# - "Fractal Gravity: Exploration of Gravitational Fields from Fractal Structures"
# - "The 3 Body Problem"
# - "Radioactive Decay of a Medical Tracer"
#
# - "Monte Carlo Estimation of the 2D Ising Model Critical Temperature"

# %% [markdown]
# Title + Motivation, 2pts

# %%
Your Motivation Paragraph

# %% [markdown]
# ## Compute what from what (Input and Output Parameters)
#
# What questions would you like to answer in the context of your problem? Provide one or several questions and include the following:
#
# A. Target outputs (quantities you will compute)
# List the primary computed quantities, with symbols and units where appropriate, e.g.
#
# - Trajectory: r(t), v(t), E(t), a(t), F(t), etc.
#
# - Temperature profile, relaxation time, gravitational field
#
# - Observable averages: average energy, heat capacity, etc.
#
# - Fit parameters (A,B,C) with uncertainty estimates
#
# B. Inputs you will start from (be explicit about what is given/assumed):
#
# - Physical parameters (masses, lengths, diffusion constants, coupling constants)
#
# - Initial/boundary conditions: are these realistic parameters
#
# - Data (is real data available for a comparison? videos available?)
#
# - Numerical controls (grid spacing, timestep, number of samples)
#
# C. Constraints and feasibility
#
# - Possible expected outcomes
#
# - Are there test cases (drop without drag, 2D Ising model, set one parameters to 0) with known results
#
# - If computation fails, is there something easier that you could extract.

# %% [markdown]
# Scientific Question(s), 2pts

# %% [markdown]
# Inputs and Outputs (with symbols/units), 2pts
# Any constraints

# %% [markdown]
# ## Model (physics + mathematics + computational method)
#
# Your model must be stated clearly enough that someone else could implement it.
#
# A. Governing equations / laws
# - Provide the core equations and define variables/parameters, e.g. (examples in class)
#
# - Ordinary differential equation (Newton's laws: $m \frac{dx^2}{dt^2} = -kx -\beta \frac{dx}{dt}$ , radioactive decay, Lotka-Volterra, ...)
#
# - Partial differential equation (Fick's law, diffusion, ...)
#
# - Stochastic: Random numbers, simulations
#
# - Quantum: solve matrix problems, diagonalize matrices, linear algebra
#
# B. Verification and Validation Plan
#
# - How will you be able to check and verify that your code works properly?
#
# - Verification: compare to known analytic solutions in a limiting case, conservation laws, convergence, symmetry checks
#
# - Validation: compare to published results, benchmark datasets, or known qualitative behavior

# %% [markdown]
# Model equations + assumptions, 2pts

# %% [markdown]
# Plan for verification/validation, 2pts
