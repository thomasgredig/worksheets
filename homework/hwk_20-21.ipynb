# %% [markdown]
# # Homework Chapters 20 and 21
#
# Numbers correspond to homework problems from [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0FL7W88TM)

# %%
import numpy.random as np
from math import log10
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %% [markdown]
# ## Chapter 20
#
# 157. Write a simulation to roll a fair 6-sided die N times and calculate the mean and standard deviation. Plot the standard deviation as a function of N for sufficient number of data points to uncover a trend.

# %%
# Solution 157

# %% [markdown]
# ## Chapter 21
#
# ---
#
# The needle in the haystack problem  illustrates the challenge of locating something small in a large area. The haystack problem was mathematically introduced by [Compte de Buffon](https://en.wikipedia.org/wiki/Buffon%27s_needle_problem)  as finding the probability $p$ that a needle of length $L$ will lie across a boundary on a striped floor. The floor has long wood panels of width $t$ and the needle can either fall onto one panel or lie across the boundary of two panels. The probability of sitting on more than one panel can be expressed analytically as $p = \frac{2}{\pi}\frac{L}{t}$.
#
# With this interesting method you can compute $\pi$ simply by counting needles; one obtains a reasonable value for $\pi$ with only 100 - 200 needles. That means that you can compute $\pi$ without a computer simply by tossing matches on the floor. *Buffon's algorithm* is expressed as follows:
#
#
# ### Needle in Haystack Algorithm
#
# 1.  Get 4 boxes of matches for a total of about $N =$ 150- 200 matches
# 2.  Determine the length $L$ of the average sized match
# 3.  Use a large piece of paper and draw horizontal lines separated by a distance $L$
# 4.  Randomly drop the matches onto the card box
# 5.  Count the number of matches $N_L$ on a line to determine $p = N_L / N$
# 6.  Calculate $\pi \approx \frac{2}{p}$
#
# ---
#
# 161.  Translate "needle in the *haystack*" algorithm into a function that returns the value of $\pi$. Add the argument $N$ to the function and find $N$, such that the answer will be have 3 significant digits; i.e. 3.14.

# %%
# Solution 161

# %% [markdown]
# 163. **(P)** Simulate 1D Brownian motion for a single particle with time step $\Delta t = 0.01$ s. Use $D = 0.5 \; \mu m^2/s$ (diffusion coefficient).
#
# **(a)**  Generate a position array $x(t)$ using random steps that are scaled by $\sqrt{2D \Delta t}$ to have a dimensionless quantity.
#
# **(b)**  Plot $x(t)$ vs. time.
#
# **(c)**  Compute the mean square displacement and verify $\langle x^2(t) \rangle = 2Dt$.

# %%
# Solution 163 part (a)

# %%
# Solution 163 part (b)

# %%
# Solution 163 part (c)

# %% [markdown]
# ---
#
# There are many diverse applications of *Fick's second law*, for example the dissolution of a sugar cube in a cup of tea, or how dopants diffuse into silicon. In the semiconductor industry, copper diffuses into silicon at elevated processing temperatures. This issue needs to be addressed with barrier layers. In biology, how oxygen and carbon dioxide diffuses across cell membranes helps us understand the body's efficiency in energy conversion. The oil industry solves PDEs to understand the [solute transport](https://www.sciencedirect.com/science/article/abs/pii/B9780323992350000014) in a porous medium. In environmental sciences, pollutants penetrate and diffuse into water sources and have a profound effect on health.
#
# For sugar dissolution, the coefficient $D$ is on the order of $5 \cdot 10^{-10}$ m<sup>2</sup> /s and depends on temperature and specific conditions. Sometimes, the coefficient can be theoretically predicted, such as by the [Stokes-Einstein-Sutherland equation](https://en.wikipedia.org/wiki/Einstein_relation) for small round particles with radius $r_p$ and viscosity $\eta$.
#
# $$
# D = \frac{k_B T}{6\pi \; \eta \; r_p}
# $$
#
# ---
#
# 165. Simulate 1000 Brownian walkers each taking $N > 10'000$ steps on a 2D lattice. This problem quantifies diffusion from discrete simulations based on the Stokes-Einstein-Sutherland equation. Use the mean squared displacement to estimate the diffusion constant $D$ assuming $\langle x^2 \rangle = 4Dt$.
#
# **(a)**  Plot $\langle x^2 \rangle$ vs. $t$
#
# **(b)**  Extract $D$ from a fit.
#
# **(c)**  How does the estimate improve with more walkers?

# %%
# Solution 165, part (a)

# %%
# Solution 165, part (b)

# %%
# Solution 165, part (c)

# %% [markdown]
# ---

# %% [markdown]
# The End.
