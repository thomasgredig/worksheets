# %% [markdown]
# # Homework Chapters 17 - 19
#
# Numbers correspond to homework problems from [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0FL7W88TM)

# %%
import numpy as np
import pandas as pd
from scipy.integrate import quad
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %% [markdown]
# ## Chapter 17
#
# 135.   Evaluate and integrate the error function $\text{erf}(b) = \frac{2}{\sqrt{\pi}} \int_0^b e^{-x^2} \; dx$ at 4 different points $b$ between 0 and 1.

# %%
# Solution 135

# %% [markdown]
# 139. Use Simpson's rule to estimate the area under the curve $f(x) = x^4 - 2x^3 + x \quad \text{on } [0, 2]$ using 10 sub-intervals. Compare the result to the exact integral and the midpoint rule.

# %%
# Solution 139 (Simpson's Rule)

# %%
# Solution 139 (Exact Solution)

# %%
# Solution 139 (Midpoint Rule)

# %% [markdown]
# ### Solution 139 (Discussion)
#
# (YOUR DISCUSSION of the THREE RESULTS GOES HERE)
#
# ---

# %% [markdown]
# 140. **(P)** The specific heat $C(T)$ can be modeled with the Einstein or Debye model.  In the Debye approximation, we have an integral that can only be solved numerically $$C(T) = 9Nk_B \left( \frac{T}{\Theta_D} \right)^3 \int_0^{\Theta_D/T} \frac{x^4 e^x}{(e^x - 1)^2} dx$$ Let $N = 1$, $k_B = 1$, $\Theta_D = 200$ K. **(a)**  Write a function to compute $C(T)$ for $T$ from 10 to 300 K. **(b)**  Use `quad()` to evaluate the integral. **(c)**  Plot $C(T)$ and comment on its behavior.

# %%
# Solution 140 (a)

# %%
# Solution 140 (b)

# %%
# Solution 140 (c)

# %% [markdown]
# ## Chapter 18
#
# 145. Import the Mauna Loa atmospheric CO2 record and select the time period from the year 2000 to today. Use a linear fit and calculate the $\chi^2$ value (the sum of the square of the residuals). Graph both data (scatter) and fit values (plot).

# %%
# Primary Mauna Loa CO_2 Record (UCSD Scripps)
url = "http://bit.ly/4iTnAtA" 
# url = "monthly_in_situ_co2_mlo.csv" (use local copy)
# source: https://scrippsco2.ucsd.edu/assets/data/atmospheric/stations/in_situ_co2/monthly/monthly_in_situ_co2_mlo.csv
df = pd.read_csv(url, header=61, skiprows=[62,63])
df
# Out:
#        Yr   Mn      Date        Date       CO2  seasonally          fit  \
# 0    1958    1     21200   1958.0411    -99.99      -99.99       -99.99
# 1    1958    2     21231   1958.1260    -99.99      -99.99       -99.99
# 2    1958    3     21259   1958.2027    315.71      314.43       316.20
# 3    1958    4     21290   1958.2877    317.45      315.15       317.30
# 4    1958    5     21320   1958.3699    317.51      314.68       317.89
# ..    ...  ...       ...         ...       ...         ...          ...
# 823  2026    8     46249   2026.6219    -99.99      -99.99       -99.99
# 824  2026    9     46280   2026.7068    -99.99      -99.99       -99.99
# 825  2026   10     46310   2026.7890    -99.99      -99.99       -99.99
# 826  2026   11     46341   2026.8740    -99.99      -99.99       -99.99
# 827  2026   12     46371   2026.9562    -99.99      -99.99       -99.99
#
#        seasonally        CO2   seasonally   Sta
# 0          -99.99     -99.99       -99.99   MLO
# ...

# %%
# Solution 145

# %% [markdown]
# ## Chapter 19
#
# 151. **(P)** Measured X-ray diffraction data of a thin film of copper phthalocyanine shows a peak centered at $2\theta = 6.8^\circ$ with Gaussian broadening. **(a)** Load the data "XRD-data.csv" and plot intensity vs. angle. **(b)** Fit the peak with a Gaussian function using `curve_fit`. A Gaussian function has the form $f(x) = b_0 + A \exp{\frac{-(x-x_0)}{2\sigma^2}}$ with 4 fitting parameters that describe the offset $b_0$, the amplitude $A$, the peak location $x_0$ and the peak width $\sigma$. **(c)** Extract the peak center and full width at half maximum (FWHM).
#
# ```python
# filename = "XRD-data.csv"
# url="https://raw.githubusercontent.com/thomasgredig/phys360/main/data/" + filename
# df = pd.read_csv(url)
# ```

# %%
# Solution 151 (a)

# %%
# Solution 151 (b)

# %%
# Solution 151 (c)

# %% [markdown]
# The End.
