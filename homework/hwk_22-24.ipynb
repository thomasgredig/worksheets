# %% [markdown]
# # Homework Chapters 22 and 24
#
# Numbers correspond to homework problems from [Introduction to Computational Physics](https://www.amazon.com/Introduction-Computational-Physics-Differential-Simulations/dp/B0FL7W88TM)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.constants as const
from uncertainties import ufloat
import uncertainties.umath as um
import pint
from sympy import *
u = pint.UnitRegistry(system='mks')

# %% [markdown]
# ## Chapter 22
#
# 167. Compute the following integral: $\int_{-\pi/2}^{\pi/2} e^x \cos(x^2) \;dx$ using a Monte Carlo method and compare your answer with the analytical result.

# %%
# Solution 167

# %% [markdown]
# 168. Create a Markov chain with 1 million samples for the following function: $f_{0.2}(x,1,3)$   in the region  $0<x<5$. Graph a histogram of the samples with a comparison to the function.$$f_\epsilon(x, y_1, y_2) = \frac{1}{2} \left[\tanh\left( \frac{x - y_1}{\epsilon} \right) - \tanh\left( \frac{x - y_2}{\epsilon} \right) \right]$$

# %%
# Solution 168

# %% [markdown]
# ## Chapter 24
#
# 175. According to the *"ant man"*, Harvard's Edward O. Wilson, the total mass of ants is about the same as that of all humans. How many ants are there on Earth? What is the total  mass using `to_compact()`? Show your work and estimates to produce the result.

# %%
# Solution 175

# %% [markdown]
# 178. **(P)** Calculate the gravitational acceleration on the surface of the Earth using $|g| = Gm_E/r_E^2$, where $m_E$ is the mass of the Earth, and $r_E$ the distance to the center of the Earth. Use a reasonable precision of the mass and radius and propagate the uncertainty to $g$.

# %%
# Solution 178.

# %% [markdown]
# 181. **(P)** Two parallel conducting, but uncharged square plates of length $L$ are separated by a small distance $a$ and separated with vacuum only. From quantum fluctuations, we find an attractive force between the plates. This was predicted by Hendrik Casimir and now known as the *Casimir force*: $F/L^2 = - \pi^2 (\hbar c) / (240 a^4)$. Calculate the force in units of nN for separation distances of 1nm and 1mm.

# %%
# Solution 181

# %% [markdown]
# The End.
